# %%
from utils.checkpoints import load_cspn_from_path
from pathlib import Path

# %%
cspn_path = Path("../checkpoints/cspn/mnist.pt")
cspn = load_cspn_from_path(ae_path)

cspn
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 cspn_path = Path("../checkpoints/cspn/mnist.pt")
# ----> 2 cspn = load_cspn_from_path(ae_path)
#       3
#       4 cspn
#
# File ~/Studium/Thesis/master-thesis/utils/checkpoints.py:68, in load_cspn_from_path(path, device)
#      66 def load_cspn_from_path(path: Path, device=None) -> AbstractCSPN:
#      67     ckpt = torch.load(path, map_location=device, weights_only=True)
# ---> 68     model = _create_cspn_from_checkpoint(ckpt["model_cfg"])
#      69     model.load_state_dict(ckpt["model_state"])
#      70     return model
#
# File ~/Studium/Thesis/master-thesis/utils/checkpoints.py:57, in _create_cspn_from_checkpoint(cfg)
#      55 def _create_cspn_from_checkpoint(cfg: dict) -> AbstractCSPN:
#      56     return Einet(
# ---> 57         num_vars=cfg["num_vars"],
# ...
